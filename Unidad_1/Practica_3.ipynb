# %% [markdown]
# <a href="https://colab.research.google.com/github/DLO-4-ya/Probabilidad-y-Estadistica/blob/main/Unidad_1/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # probabilidad y estadistica
# # unidad 1
# ## practica 3: **Máximo, mínimo, Rango y dispersión de datos**
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno: Dante Manuel Ruvalcaba Martinez

# %%
import random
import matplotlib.pyplot as plt
from statistics import mean , median, mode
import numpy as np

# %%
import random
fabricas1=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabricas1.append(numero_aleatorio)
print(fabricas1)
# Out:
# [55.27, 62.0, 54.71, 56.76, 82.44, 71.77, 66.31, 81.91, 98.02, 82.17, 92.5, 81.35, 64.98, 98.46, 53.21, 81.65, 73.61, 80.42, 61.84, 79.03, 98.54, 86.82, 92.2, 55.71, 72.59, 94.89, 74.69, 57.33, 89.36, 55.15, 86.79, 65.84, 93.79, 55.06, 82.37, 77.22, 97.78, 62.31, 58.22, 92.11, 53.47, 87.87, 87.68, 53.51, 80.02, 79.08, 61.29, 55.95, 68.17, 59.86, 96.73, 79.44, 98.1, 59.4, 61.53, 79.26, 51.8, 94.82, 77.79, 68.97, 50.94, 59.58, 51.55, 66.83, 75.21, 68.48, 87.37, 87.41, 74.48, 56.39, 88.4, 58.56, 80.52, 89.92, 72.79, 71.0, 89.87, 57.85, 75.42, 81.05, 77.92, 62.77, 67.15, 94.88, 63.93, 87.23, 77.38, 84.17, 69.79, 73.8, 90.32, 61.79, 98.91, 68.32, 54.54, 71.03, 98.42, 78.95, 66.43, 62.89]

# %%
import random
fabricas2=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabricas2.append(numero_aleatorio)
print(fabricas2)
# Out:
# [80.66, 82.16, 87.95, 76.38, 71.6, 74.46, 98.0, 60.19, 56.64, 65.28, 86.52, 79.92, 73.62, 94.45, 94.4, 66.23, 80.85, 92.62, 67.32, 57.06, 71.45, 87.77, 65.71, 95.0, 63.79, 68.64, 57.88, 93.96, 82.76, 86.1, 57.86, 53.22, 99.64, 90.46, 77.51, 84.7, 81.74, 71.62, 80.83, 90.47, 72.27, 76.54, 52.29, 61.27, 80.72, 84.82, 58.22, 50.95, 81.17, 62.96, 62.16, 53.92, 94.56, 67.39, 55.62, 57.51, 76.82, 92.04, 72.0, 97.46, 92.54, 89.94, 90.84, 89.82, 51.69, 97.31, 76.35, 87.95, 75.79, 80.26, 72.29, 93.47, 83.14, 86.08, 56.08, 53.4, 64.02, 67.63, 52.91, 50.47, 81.84, 55.73, 79.98, 58.98, 72.32, 80.92, 85.19, 63.36, 66.03, 65.57, 75.33, 69.38, 92.97, 72.16, 51.88, 93.93, 74.69, 74.5, 83.83, 80.28]

# %%
maximo1=max(fabricas1)
minimo1=min(fabricas1)
rango1=maximo1-minimo1
media1=mean(fabricas1)
mediana1=median(fabricas1)
moda1=mode(fabricas1)
print( "estadistica descriptiva de la fabrica 1\n" , "media: " , media1 , "\nmediana: " , mediana1 , "\nmoda: " , moda1 , "\n ,rango: " , rango1 , "\nmaximo: " , maximo1 , "\nminimo: " , minimo1)
# Out:
# estadistica descriptiva de la fabrica 1
#  media:  74.3616
# mediana:  74.58500000000001
# moda:  55.27
#  ,rango:  47.97
# maximo:  98.91
# minimo:  50.94

# %%
maximo2=max(fabricas2)
minimo2=min(fabricas2)
rango2=maximo2-minimo2
media2=mean(fabricas2)
mediana2=median(fabricas2)
moda2=mode(fabricas2)
print( "estadistica descriptiva de la fabrica 2\n" , "media: " , media2 , "\nmediana: " , mediana2 , "\nmoda: " , moda2 , "\n ,rango: " , rango2 , "\nmaximo: " , maximo2 , "\nminimo: " , minimo2)
# Out:
# estadistica descriptiva de la fabrica 2
#  media:  75.0896
# mediana:  76.07
# moda:  87.95
#  ,rango:  49.17
# maximo:  99.64
# minimo:  50.47

# %%
desviacion_estandar1 = np.std(fabricas1)
print(desviacion_estandar1)
# Out:
# 14.124831306603276

# %%
desviacion_estandar2 = np.std(fabricas2)
print(desviacion_estandar2)
# Out:
# 13.664716529807706

# %%
figsize = (8, 6)
plt.figure(figsize=figsize)
plt.hist(fabricas1, bins=10, alpha=0.2, color="b", edgecolor="black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label=f"media={media2:.2f}")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana2:.2f}")
plt.axvline(moda1, color="g", linestyle="dashed", linewidth=2, label=f"moda={moda2:.2f}")
plt.axvline(desviacion_estandar1, color="y", linestyle="dashed", linewidth=2, label=f"desviacion_estandar={desviacion_estandar2:.2f}")
plt
plt.title("Producción diaria de la fábrica 1")
plt.legend()
plt.show()

# %%
figsize = (8, 6)
plt.figure(figsize=figsize)
plt.hist(fabricas2, bins=10, alpha=0.2, color="b", edgecolor="black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label=f"media={media2:.2f}")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana2:.2f}")
plt.axvline(moda2, color="g", linestyle="dashed", linewidth=2, label=f"moda={moda2:.2f}")
plt.axvline(desviacion_estandar2, color="y", linestyle="dashed", linewidth=2, label=f"desviacion_estandar={desviacion_estandar2:.2f}")
plt
plt.title("Producción diaria de la fábrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns # Import the seaborn library and assign it the alias 'sns'
sns.set_theme(style="whitegrid")

# %%
sns.histplot(fabricas1, bins=10, kde=True, color="b", edgecolor="black")
# Out:
# <Axes: ylabel='Count'>
