# %% [markdown]
# <a href="https://colab.research.google.com/github/DLO-4-ya/Probabilidad-y-Estadistica/blob/main/Unidad_1/practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # probabilidad y estadistica
# # unidad 1
# ## practica 1: **estadistica decriptiva e histogramas**
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno: Dante Manuel Ruvalcaba Martinez

# %%
from statistics import *
# lista de calificaciones
grupoa=[70,70,65,67,75,100,20,100,96]
print(grupoa)
type(grupoa)
# Out:
# [70, 70, 65, 67, 75, 100, 20, 100, 96]
# list

# %%
#sacar la media de todas las calificaciones
prom= sum(grupoa) / len(grupoa)
print(prom)
# Out:
# 73.66666666666667

# %%
#sacar el promedio mediante la funcion mean
prom2 = mean(grupoa)
print(prom2)
# Out:
# 73.66666666666667

# %%
#sacar la mediana de las calificaciones
median = median(grupoa)
print(median)
# Out:
# 70

# %%
#sacar la moda de las calificaciones
mode = mode(grupoa)
print(mode)
# Out:
# 70
